# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/TASK2.csv')
df.head()
# Out:
#       kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2  10811496  K00753.01           NaN       CANDIDATE        CANDIDATE
# 3  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  ...  \
# 0      1.000              0              0              0              0  ...
# 1      0.969              0              0              0              0  ...
# 2      0.000              0              0              0              0  ...
# 3      0.000              0              1              0              0  ...
# 4      1.000              0              0              0              0  ...
#
#    koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# ...

# %%
df.shape
# Out:
# (9564, 49)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 49 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   kepid              9564 non-null   int64
#  1   kepoi_name         9564 non-null   object
#  2   kepler_name        2359 non-null   object
#  3   koi_disposition    9564 non-null   object
#  4   koi_pdisposition   9564 non-null   object
#  5   koi_score          8054 non-null   float64
#  6   koi_fpflag_nt      9564 non-null   int64
#  7   koi_fpflag_ss      9564 non-null   int64
#  8   koi_fpflag_co      9564 non-null   int64
#  9   koi_fpflag_ec      9564 non-null   int64
#  10  koi_period         9564 non-null   float64
#  11  koi_period_err1    9110 non-null   float64
#  12  koi_period_err2    9110 non-null   float64
#  13  koi_time0bk        9564 non-null   float64
#  14  koi_time0bk_err1   9110 non-null   float64
#  15  koi_time0bk_err2   9110 non-null   float64
# ...

# %%
df = df.drop(['kepid', 'kepoi_name', 'kepler_name', 'koi_pdisposition', 'koi_score','koi_teq_err1', 'koi_teq_err2'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 42 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   koi_disposition    9564 non-null   object
#  1   koi_fpflag_nt      9564 non-null   int64
#  2   koi_fpflag_ss      9564 non-null   int64
#  3   koi_fpflag_co      9564 non-null   int64
#  4   koi_fpflag_ec      9564 non-null   int64
#  5   koi_period         9564 non-null   float64
#  6   koi_period_err1    9110 non-null   float64
#  7   koi_period_err2    9110 non-null   float64
#  8   koi_time0bk        9564 non-null   float64
#  9   koi_time0bk_err1   9110 non-null   float64
#  10  koi_time0bk_err2   9110 non-null   float64
#  11  koi_impact         9201 non-null   float64
#  12  koi_impact_err1    9110 non-null   float64
#  13  koi_impact_err2    9110 non-null   float64
#  14  koi_duration       9564 non-null   float64
#  15  koi_duration_err1  9110 non-null   float64
# ...

# %%
df.groupby('koi_disposition').size()
# Out:
# koi_disposition
# CANDIDATE         2367
# CONFIRMED         2357
# FALSE POSITIVE    4840
# dtype: int64

# %%
df = df[df['koi_disposition'] != 'CANDIDATE']
df.shape
# Out:
# (7197, 42)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7197 entries, 0 to 9563
# Data columns (total 42 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   koi_disposition    7197 non-null   object
#  1   koi_fpflag_nt      7197 non-null   int64
#  2   koi_fpflag_ss      7197 non-null   int64
#  3   koi_fpflag_co      7197 non-null   int64
#  4   koi_fpflag_ec      7197 non-null   int64
#  5   koi_period         7197 non-null   float64
#  6   koi_period_err1    6863 non-null   float64
#  7   koi_period_err2    6863 non-null   float64
#  8   koi_time0bk        7197 non-null   float64
#  9   koi_time0bk_err1   6863 non-null   float64
#  10  koi_time0bk_err2   6863 non-null   float64
#  11  koi_impact         6939 non-null   float64
#  12  koi_impact_err1    6863 non-null   float64
#  13  koi_impact_err2    6863 non-null   float64
#  14  koi_duration       7197 non-null   float64
#  15  koi_duration_err1  6863 non-null   float64
# ...

# %%
missing_error_attribute_names = [attr for attr in df.columns if "err" in attr]
print(missing_error_attribute_names)
# Out:
# ['koi_period_err1', 'koi_period_err2', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact_err1', 'koi_impact_err2', 'koi_duration_err1', 'koi_duration_err2', 'koi_depth_err1', 'koi_depth_err2', 'koi_prad_err1', 'koi_prad_err2', 'koi_insol_err1', 'koi_insol_err2', 'koi_steff_err1', 'koi_steff_err2', 'koi_slogg_err1', 'koi_slogg_err2', 'koi_srad_err1', 'koi_srad_err2']

# %%
df = df[['koi_disposition','koi_fpflag_nt','koi_fpflag_ss','koi_fpflag_co','koi_fpflag_ec','koi_period','koi_time0bk','koi_impact','koi_duration','koi_depth','koi_prad','koi_teq','koi_insol','koi_model_snr','koi_tce_plnt_num','koi_steff','koi_slogg','koi_srad','ra','dec','koi_kepmag']]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7197 entries, 0 to 9563
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   koi_disposition   7197 non-null   object
#  1   koi_fpflag_nt     7197 non-null   int64
#  2   koi_fpflag_ss     7197 non-null   int64
#  3   koi_fpflag_co     7197 non-null   int64
#  4   koi_fpflag_ec     7197 non-null   int64
#  5   koi_period        7197 non-null   float64
#  6   koi_time0bk       7197 non-null   float64
#  7   koi_impact        6939 non-null   float64
#  8   koi_duration      7197 non-null   float64
#  9   koi_depth         6939 non-null   float64
#  10  koi_prad          6939 non-null   float64
#  11  koi_teq           6939 non-null   float64
#  12  koi_insol         6978 non-null   float64
#  13  koi_model_snr     6939 non-null   float64
#  14  koi_tce_plnt_num  6913 non-null   float64
#  15  koi_steff         6939 non-null   float64
# ...

# %%
df_new1 = df.copy()

# %%
df_new1['koi_disposition'] = df_new1['koi_disposition'].map({'CONFIRMED': 1, 'FALSE POSITIVE': 0})
df_new1.head()
# Out:
#    koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0                1              0              0              0
# 1                1              0              0              0
# 3                0              0              1              0
# 4                1              0              0              0
# 5                1              0              0              0
#
#    koi_fpflag_ec  koi_period  koi_time0bk  koi_impact  koi_duration  \
# 0              0    9.488036   170.538750       0.146       2.95750
# 1              0   54.418383   162.513840       0.586       4.50700
# 3              0    1.736952   170.307565       1.276       2.40641
# 4              0    2.525592   171.595550       0.701       1.65450
# 5              0   11.094321   171.201160       0.538       4.59450
#
#    koi_depth  ...  koi_teq  koi_insol  koi_model_snr  koi_tce_plnt_num  \
# 0      616.0  ...    793.0      93.59           35.8               1.0
# ...

# %%
feature_columns = df_new1.columns[df_new1.columns != 'koi_disposition']
target_column = 'koi_disposition'

# %%
X = df_new1[feature_columns]
y = df_new1[target_column]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10],
    'penalty': ['none', 'l2'],
}

# %%
log_reg = LogisticRegression()
